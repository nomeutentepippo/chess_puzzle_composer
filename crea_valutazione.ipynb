# %%
import pandas as pd
import math
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
import numpy as np
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('max_colwidth', 100)
from os.path import exists
from stockfish import Stockfish
import chess
import chess.engine
import chess.pgn
import random
import time
from joblib import Parallel, delayed
import multiprocessing
import pickle
import os
import logging
import func_timeout
stockfishpath=r"C:\Program Files\stockfish_15_win_x64_avx2\stockfish_15_x64_avx2.exe"
from libreria_analisi import analyze_all_fens
from lib_crea_random_pos import get_valid_random_fens
from  lib_load_fen_data import load_m8_list, parse_png

# %%
import psutil

def kill_pending_stockfish_process():
    PROCNAME = "stockfish_15_x64_avx2.exe"
    for proc in psutil.process_iter():
        # check whether the process name matches
        if proc.name() == PROCNAME:
            proc.kill()

# %%
logging.basicConfig(filename=r'C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\logsss.txt',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.INFO)

logging.info("START")

logger = logging.getLogger('urbanGUI')

# %%
m8n2_fen = load_m8_list(r'C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\m8n2.txt',6)
m8n3_fen = load_m8_list(r'C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\m8n3.txt',6)
m8n4_fen = load_m8_list(r'C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\m8n4.txt',6)

# %%
pgn_dir = r'C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions'
pgns = {}
for file in os.listdir(pgn_dir):
    if file.endswith(".pgn"):
        print(os.path.join(pgn_dir, file))
        pgn_parsed=parse_png(os.path.join(pgn_dir, file))
        pgns[file]=pgn_parsed
df_pgns = pd.concat(pgns.values(), axis=0, keys=pgns.keys())
# Out:
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\1csalbum.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\3ALBUM.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\4ALBUM.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\5alb_eg.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\bestyear.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\cs200304.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\cs9798.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\cs9900.pgn
# C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\puzzles\compositions\CS_0910.pgn
# ...

# %%
all_evaluation_m8n2, total_time = analyze_all_fens(df_pgns.loc[[('bestyear.pgn',0)]]['fen'], problem_type=666, multi_thread=False)
all_evaluation_m8n2
# Out:
# IntProgress(value=0, max=1)
# depth_level          depth_5                                                                                                                                                 depth_10                                                                                                                                                depth_15                                                                                                                                                 depth_20                                                                                                                                                 depth_25                                                                                                                                                                        fen total_time problem_type
# ...

# %%
get_all_analyses('8/8/R3b3/8/8/1k1K4/1p6/1nR5 w - - 0 1')

# %%
engine = chess.engine.SimpleEngine.popen_uci(stockfishpath)
chess.Board('8/8/R3b3/8/8/1k1K4/1p6/1nR5 w - - 0 1')

# %%
file_name = "all_evaluation_m8n3.pkl"
parallel_analyze_in_chunks(m8n3_fen, 3, file_name, folder_output, multiplier_size_chunk = 2)
print(f'{file_name} done.')
time.sleep(60)

file_name = "all_evaluation_m8n4.pkl"
parallel_analyze_in_chunks(m8n4_fen, 4, file_name, folder_output, multiplier_size_chunk = 2)
print(f'{file_name} done.')
time.sleep(60)

file_name = "all_evaluation_pgn_compositions.pkl"
parallel_analyze_in_chunks(df_pgns, 666, file_name, folder_output, multiplier_size_chunk = 2)
print(f'{file_name} done.')
time.sleep(60)

os.system("shutdown /s /t 1")

# %%
file_name = "all_evaluation_pgn_compositions.pkl"
folder_output = r'C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles'
parallel_analyze_in_chunks(df_pgns, 666, file_name, folder_output, multi_thread_ = False, multiplier_size_chunk = 2, restart_from_chunk_n=13)
print(f'{file_name} done.')

# %%
all_evaluation_m8n2, total_time = analyze_all_fens(m8n2_fen['fen'], problem_type=2, multi_thread=True)
print(f'm8n2: {total_time}')
all_evaluation_m8n2.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_m8n2.pkl")
time.sleep(60*5)

all_evaluation_m8n3, total_time = analyze_all_fens(m8n3_fen['fen'], problem_type=3, multi_thread=True)
print(f'm8n3: {total_time}')
all_evaluation_m8n3.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_m8n3.pkl")
time.sleep(60*5)

all_evaluation_m8n4, total_time = analyze_all_fens(m8n4_fen['fen'], problem_type=4, multi_thread=True)
print(f'm8n4: {total_time}')
all_evaluation_m8n4.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_m8n4.pkl")
time.sleep(60*5)

all_evaluation_m8 = pd.concat([all_evaluation_m8n2, all_evaluation_m8n3, all_evaluation_m8n4], ignore_index=True)      
all_evaluation_m8.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_m8.pkl")

all_evaluation_pgn_compositions, total_time = analyze_all_fens(df_pgns['fen'], problem_type=666, multi_thread=True)
print(f'compositions: {total_time}')
all_evaluation_pgn_compositions.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_pgn_compositions.pkl")

#os.system("shutdown /s /t 1")

# %%
valid_random_fens_1 = get_valid_random_fens(5,12,100)
print(valid_random_fens_1.shape)
all_evaluation_random_pos_1, total_time = analyze_all_fens(valid_random_fens_1['fen'], problem_type=0, multi_thread=False)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_1.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_21072022.pkl")
# Out:
# (800, 2)
# IntProgress(value=0, max=800)
# An exception occurred
# list index out of range
# fen: 3K4/3b4/8/4q3/3kP3/1n4r1/8/6q1 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 4k1K1/2n5/8/8/6P1/2q5/1q6/6rn w - - 0 1
#
# An exception occurred
# list index out of range
# fen: q2k4/5K2/7q/7p/1n4bP/6b1/8/8 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 5K1k/6r1/5n2/b7/7q/2pr4/2P5/8 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 5bq1/3b4/P4K2/8/n5b1/8/2p2kr1/5r2 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 8/7p/6p1/5r1k/1q1b1r2/1P6/3pK3/q7 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: b5k1/7n/K1n4q/2b5/3b4/P2r4/P6q/8 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 8/7n/1P3qpq/1r2n3/8/6k1/Kb1q4/4r3 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 8/2nrb2b/2p5/1b6/1r6/8/k2n4/2q3BK w - - 0 1
#
# random_pos: 35551.9556851387

# %%
valid_random_fens_1 = get_valid_random_fens(15,16,50)
print(valid_random_fens_1.shape)
all_evaluation_random_pos_1, total_time = analyze_all_fens(valid_random_fens_1['fen'], problem_type=0, multi_thread=False)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_1.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_15-16_man.pkl")
# Out:
# (100, 2)
# IntProgress(value=0)
# An exception occurred
# list index out of range
# fen: 2n2n2/6k1/1b5b/1p4qr/3b1p2/1b5P/5rb1/1K4b1 w - - 0 1
#
# random_pos: 7720.661112070084

# %%
valid_random_fens_1 = get_valid_random_fens(17,18,50)
print(valid_random_fens_1.shape)
all_evaluation_random_pos_1, total_time = analyze_all_fens(valid_random_fens_1['fen'], problem_type=0, multi_thread=False)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_1.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_17-18_man.pkl")
# Out:
# (100, 2)
# IntProgress(value=0)
# Exception in callback Protocol._line_received('readyok')
# handle: <Handle Protocol._line_received('readyok')>
# Traceback (most recent call last):
#   File "C:\Users\Giorgio\anaconda3\envs\myenv\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Giorgio\anaconda3\envs\myenv\lib\site-packages\chess\engine.py", line 1040, in _line_received
#     self.command._line_received(self, line)
#   File "C:\Users\Giorgio\anaconda3\envs\myenv\lib\site-packages\chess\engine.py", line 1291, in _line_received
#     self.line_received(engine, line)
#   File "C:\Users\Giorgio\anaconda3\envs\myenv\lib\site-packages\chess\engine.py", line 1610, in line_received
#     self._readyok(engine)
#   File "C:\Users\Giorgio\anaconda3\envs\myenv\lib\site-packages\chess\engine.py", line 1617, in _readyok
#     engine._go(limit, root_moves=root_moves)
# ...

# %%
valid_random_fens_1 = get_valid_random_fens(5,10,150)
print(valid_random_fens_1.shape)
all_evaluation_random_pos_1, total_time = analyze_all_fens(valid_random_fens_1['fen'], problem_type=0, multi_thread=False)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_1.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_5-10_man-150x.pkl")
# Out:
# (900, 2)
# IntProgress(value=0, max=900)
# An exception occurred
# list index out of range
# fen: 4K3/2k1P3/4r3/8/8/3q4/8/8 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 8/8/8/3kP3/8/b7/4r1qq/K7 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 2qQK3/3p4/8/5r2/r4r2/8/8/4k3 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 1k6/6b1/2q5/5K2/7P/3pq2r/8/8 w - - 0 1
#
# An exception occurred
# list index out of range
# fen: 8/7r/2n5/1KP1k2n/2P5/1b2p3/8/7b w - - 0 1
#
# random_pos: 36186.263206243515

# %%
fens=['3K4/8/8/p2k4/pp1B4/N5N1/P2Q4/8 w - - 0 1', 
      '3R4/8/8/8/1r4kB/1B2K3/8/8 w - - 0 1',
     '8/8/8/4p3/4P1KB/1pN1k3/1p6/1Q6 w - - 0 1',
     '7k/6pB/6K1/8/8/5Pn1/1P6/8 w - - 0 1',
     '2K5/4k3/RB5p/2R4B/8/8/8/8 w - - 0 1']
all_evaluation_random_pos_1, total_time = analyze_all_fens(fens, problem_type=0, multi_thread=False)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_1.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_sei_problemi.pkl")
# Out:
# IntProgress(value=0, max=5)
# random_pos: 48.78225231170654

# %%
get_all_analyses('3K4/8/8/p2k4/pp1B4/N5N1/P2Q4/8 w - - 0 1')
# Out:
# depth_level          depth_5                                                                                                                                                  depth_10                                                                                                                                                  depth_15                                                                                                                                            depth_20                                                                                                                                             depth_25                                                                                                                                                                         fen total_time
# ...

# %%
## RANDOM

#time.sleep(60*60*2)
valid_random_fens_1 = get_valid_random_fens(5,14,50)
print(valid_random_fens_1.shape)
all_evaluation_random_pos_1, total_time = analyze_all_fens(valid_random_fens_1['fen'], problem_type=0, multi_thread=True)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_1.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_1.pkl")

valid_random_fens_2 = get_valid_random_fens(5,14,50)
all_evaluation_random_pos_2, total_time = analyze_all_fens(valid_random_fens_2['fen'], problem_type=0, multi_thread=True)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_2.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_2.pkl")

valid_random_fens_3 = get_valid_random_fens(5,14,50)
all_evaluation_random_pos_3, total_time = analyze_all_fens(valid_random_fens_3['fen'], problem_type=0, multi_thread=True)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_3.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_3.pkl")

valid_random_fens_4 = get_valid_random_fens(5,14,50)
all_evaluation_random_pos_4, total_time = analyze_all_fens(valid_random_fens_4['fen'], problem_type=0, multi_thread=True)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_4.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_4.pkl")

valid_random_fens_5 = get_valid_random_fens(5,14,50)
all_evaluation_random_pos_5, total_time = analyze_all_fens(valid_random_fens_5['fen'], problem_type=0, multi_thread=True)
print(f'random_pos: {total_time}')      
all_evaluation_random_pos_5.to_pickle(r"C:\Users\Giorgio\Documents\Python Scripts\Scacchi puzzle\chess_puzzles\all_evaluation_random_pos_5.pkl")

#os.system("shutdown /s /t 1")
